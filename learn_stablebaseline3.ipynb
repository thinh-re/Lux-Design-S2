# %%
import gym

from stable_baselines3 import PPO

env = gym.make("CartPole-v1")

model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10_000)

vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action)
    vec_env.render()
    # VecEnv resets automatically
    # if done:
    #   obs = env.reset()

env.close()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.2     |
# |    ep_rew_mean     | 23.2     |
# | time/              |          |
# |    fps             | 1445     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.9        |
# |    ep_rew_mean          | 25.9        |
# | time/                   |             |
# |    fps                  | 987         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008082742 |
# |    clip_fraction        | 0.0849      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | 0.00513     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.76        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 58.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.5         |
# |    ep_rew_mean          | 32.5         |
# | time/                   |              |
# |    fps                  | 867          |
# |    iterations           | 3            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0094393585 |
# |    clip_fraction        | 0.0663       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.672       |
# |    explained_variance   | 0.0707       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11           |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0166      |
# |    value_loss           | 33.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42          |
# |    ep_rew_mean          | 42          |
# | time/                   |             |
# |    fps                  | 800         |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013898728 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.638      |
# |    explained_variance   | 0.241       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0213     |
# |    value_loss           | 50.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.6        |
# |    ep_rew_mean          | 58.6        |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 5           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.014336135 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.602      |
# |    explained_variance   | 0.333       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.8        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.023      |
# |    value_loss           | 59.1        |
# -----------------------------------------
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Documents/Projects/Lux-Design-S2/env/lib/python3.10/site-packages/gym/envs/classic_control/rendering.py:15
#      14 try:
# ---> 15     import pyglet
#      16 except ImportError as e:
#
# ModuleNotFoundError: No module named 'pyglet'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 15
#      13     action, _states = model.predict(obs, deterministic=True)
#      14     obs, reward, done, info = vec_env.step(action)
# ---> 15     vec_env.render()
#      16     # VecEnv resets automatically
#      17     # if done:
#      18     #   obs = env.reset()
#      20 env.close()
#
# File ~/Documents/Projects/Lux-Design-S2/env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:98, in DummyVecEnv.render(self, mode)
#      86 """
#      87 Gym environment rendering. If there are multiple environments then
#      88 they are tiled together in one image via ``BaseVecEnv.render()``.
#    (...)
#      95 :param mode: The rendering type.
#      96 """
#      97 if self.num_envs == 1:
# ---> 98     return self.envs[0].render(mode=mode)
#      99 else:
#     100     return super().render(mode=mode)
#
# File ~/Documents/Projects/Lux-Design-S2/env/lib/python3.10/site-packages/gym/core.py:295, in Wrapper.render(self, mode, **kwargs)
#     294 def render(self, mode="human", **kwargs):
# --> 295     return self.env.render(mode, **kwargs)
#
# File ~/Documents/Projects/Lux-Design-S2/env/lib/python3.10/site-packages/gym/core.py:295, in Wrapper.render(self, mode, **kwargs)
#     294 def render(self, mode="human", **kwargs):
# --> 295     return self.env.render(mode, **kwargs)
#
# File ~/Documents/Projects/Lux-Design-S2/env/lib/python3.10/site-packages/gym/envs/classic_control/cartpole.py:179, in CartPoleEnv.render(self, mode)
#     176 cartheight = 30.0
#     178 if self.viewer is None:
# --> 179     from gym.envs.classic_control import rendering
#     181     self.viewer = rendering.Viewer(screen_width, screen_height)
#     182     l, r, t, b = -cartwidth / 2, cartwidth / 2, cartheight / 2, -cartheight / 2
#
# File ~/Documents/Projects/Lux-Design-S2/env/lib/python3.10/site-packages/gym/envs/classic_control/rendering.py:17
#      15     import pyglet
#      16 except ImportError as e:
# ---> 17     raise ImportError(
#      18         """
#      19     Cannot import pyglet.
#      20     HINT: you can install pyglet directly via 'pip install pyglet'.
#      21     But if you really just want to install all Gym dependencies and not have to think about it,
#      22     'pip install -e .[all]' or 'pip install gym[all]' will do it.
#      23     """
#      24     )
#      26 try:
#      27     from pyglet.gl import *
#
# ImportError:
#     Cannot import pyglet.
#     HINT: you can install pyglet directly via 'pip install pyglet'.
#     But if you really just want to install all Gym dependencies and not have to think about it,
#     'pip install -e .[all]' or 'pip install gym[all]' will do it.
